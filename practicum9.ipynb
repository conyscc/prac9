# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
key='Wr6laEK7t2jma0KUbdGm5r7eGIA8aFRqS7wLFu9b'
url=f'https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?earth_date=2022-3-10&api_key={key}'
r = requests.get(url)
photos = r.json()['photos']

# %%
import matplotlib.pyplot as plt
from skimage import io

# %%
fig, ax = plt.subplots(3, 1, figsize=(15, 15))
for i in range(3):
    f = photos[i]['img_src']
    a = io.imread(f)
    ax[i].imshow(a, cmap='gray')
